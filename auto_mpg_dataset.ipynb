# %% [markdown]
# <a href="https://colab.research.google.com/github/Dayxxn343/auto_mpg-Linear-Regression/blob/main/auto_mpg_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from google.colab import drive
drive.mount('/content/drive')
from sklearn.model_selection import train_test_split
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# @title 자동차 연비에 대한 선형회귀학습
# data download
file_path = '/content/drive/My Drive/auto_mpg.csv'
data = pd.read_csv(file_path)
data
# Out:
#      displacement  weight   mpg
# 0           307.0    3504  18.0
# 1           350.0    3693  15.0
# 2           318.0    3436  18.0
# 3           304.0    3433  16.0
# 4           302.0    3449  17.0
# ..            ...     ...   ...
# 393         140.0    2790  27.0
# 394          97.0    2130  44.0
# 395         135.0    2295  32.0
# 396         120.0    2625  28.0
# 397         119.0    2720  31.0
#
# [398 rows x 3 columns]

# %%
#설명변수랑 종속변수 나누기
X = data[['displacement', 'weight']]
y = data['mpg']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
print("Train dataset:")
print(X_train.head())
print(y_train.head())
print("\nTest dataset:")
print(X_test.head())
print(y_test.head())
# Out:
# Train dataset:
#      displacement  weight
# 307         173.0    2700
# 55           97.0    1834
# 76          121.0    2933
# 25          360.0    4615
# 82          120.0    2506
# 307    26.8
# 55     27.0
# 76     18.0
# 25     10.0
# 82     23.0
# Name: mpg, dtype: float64
#
# Test dataset:
#      displacement  weight
# 198          91.0    1795
# 396         120.0    2625
# 33          232.0    2634
# 208         318.0    3940
# 93          318.0    4237
# 198    33.0
# 396    28.0
# 33     19.0
# 208    13.0
# 93     14.0
# Name: mpg, dtype: float64

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
r2 = r2_score(y_test, y_pred)
print("결정계수:", r2)
# Out:
# 결정계수: 0.7093257632122613

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 회귀식 정의
w1, w2, b = 1, 2, 3  # 임의의 계수 및 절편 설정

# 데이터 생성
x1 = np.linspace(-5, 5, 100)
x2 = np.linspace(-5, 5, 100)
x1, x2 = np.meshgrid(x1, x2)
y = w1 * x1 + w2 * x2 + b

# 그래프 그리기
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x1, x2, y, alpha=0.5)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('y')
ax.set_title('3D Linear Regression')
plt.show()
